# %% [markdown]
# # This Notebook is for testing feature engineering classes
# It uses the feature_engineering.py file which we can use in our pipeline
#
# Each class can be tested here on a train_mini to make sure it works

# %%
## Import our feature engineering classes
import sys
sys.path.insert(0, '../code/')

import feature_engineering as fe

# %%
import pandas as pd

# %%
# Load Data
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

# %%
train_df.head()
train_df.shape

# %%
# create small train to test on
train_mini = train_df.head(5000)

# %%
### I NEED TO READ THIS ####
# http://michelleful.github.io/code-blog/2015/06/20/pipelines/

# And this
# http://adataanalyst.com/machine-learning/comprehensive-guide-feature-engineering/

questions = ('question1', 'question2', )

# %% [markdown]
# ## FuzzyFeatures Class (Not Working)

# %%
fuz = fe.FuzzyFeatures

#fuz.fit(train_df, questions)
#fuz.transform(questions, train_df)

# %%
# WHY DOESNT THIS WORK? !@#$!@#$!@#$!@#$!
wm = fe.WordMatchShare()
wm.transform(train_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-154-3b3a8862c89f> in <module>()
#       1 # WHY DOESNT THIS WORK?
# ----> 2 wm.transform(train_df)
#
# /Users/robmulla/Google Drive/Kaggle/kagglequora/code/feature_engineering.py in transform(self, X, y)
#      91
#      92     def transform(self, X, y = None):
# ---> 93         X['tfidf_word_match_share'] = X.apply(self.tfidf_word_match_share, axis=1, raw=True)
#      94
#      95         X['word_match_share'] = X.apply(self.word_match_share, axis=1, raw=True)
#
# NameError: name 'word_match_share' is not defined

# %% [markdown]
# ## SentimentFeatures Class Test (Working)

# %%
sf = fe.SentimentFeatures
sf.transform(questions, train_mini)
# Out:
# ../code/feature_engineering.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ../code/feature_engineering.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   def transform(self, X, y = None):
#         id  qid1  qid2                                          question1  \
# 0        0     1     2  What is the step by step guide to invest in sh...
# 1        1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2        2     5     6  How can I increase the speed of my internet co...
# ...

# %%
def transform(X):
    sid = SentimentIntensityAnalyzer()
    X['q1_polarity'] = X.question1.apply(lambda row: sid.polarity_scores(str(row))['compound'])
    X['q2_polarity'] = X.question2.apply(lambda row: sid.polarity_scores(str(row))['compound'])
    return X

# %%
transform(train_small)
# Out:
# /Users/robmulla/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/robmulla/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id  qid1  qid2                                          question1  \
# 0        0     1     2  What is the step by step guide to invest in sh...
# 1        1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# ...
